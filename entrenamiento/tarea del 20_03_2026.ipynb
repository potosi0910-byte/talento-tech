# %%
import pandas as pd
import math
# librerías

#variables
b0 = 62.4
b1 = 1.55
b2 = 0.51
b3 = 0.1
b4 = -0.14

# datos
datos1 = [78.5,74.3,104.3,87.6,95.9,109.2,102.7,72.5,93.1,115.9,83.8,113.3,109.4]
datos2 = [7,1,11,11,7,11,3,1,2,21,1,11,10]
datos3 = [26,29,56,31,52,55,71,31,54,47,40,66,68]
datos4 = [6,15,8,8,6,9,17,22,18,4,23,9,8]
datos5 = [60,52,20,47,33,22,6,44,22,26,34,12,12]

# diccionario
diccionario = {"y":datos1,
               "x1":datos2,
               "x2":datos3,
               "x3":datos4,
               "x4":datos5,}

#tabla
df= pd.DataFrame(diccionario)
df


# nuevas columnas
df['ypred'] = b0 + b1*df['x1'] + b2*df['x2'] + b3*df['x3']

df['y-pred'] = df['y'] - df['ypred']

df['y-pred^2'] = df['y-pred'] ** 2

df
# Out:
#         y  x1  x2  x3  x4   ypred  y-pred  y-pred^2
# 0    78.5   7  26   6  60   87.11   -8.61   74.1321
# 1    74.3   1  29  15  52   80.24   -5.94   35.2836
# 2   104.3  11  56   8  20  108.81   -4.51   20.3401
# 3    87.6  11  31   8  47   96.06   -8.46   71.5716
# 4    95.9   7  52   6  33  100.37   -4.47   19.9809
# 5   109.2  11  55   9  22  108.40    0.80    0.6400
# 6   102.7   3  71  17   6  104.96   -2.26    5.1076
# 7    72.5   1  31  22  44   81.96   -9.46   89.4916
# 8    93.1   2  54  18  22   94.84   -1.74    3.0276
# 9   115.9  21  47   4  26  119.32   -3.42   11.6964
# 10   83.8   1  40  23  34   86.65   -2.85    8.1225
# 11  113.3  11  66   9  12  114.01   -0.71    0.5041
# 12  109.4  10  68   8  12  113.38   -3.98   15.8404
